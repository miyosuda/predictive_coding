# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from dataset import Dataset
dataset = Dataset()

# %%
plt.figure()
plt.imshow(dataset.images[0], cmap='gray')
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(dataset.filtered_images[0], cmap='gray')
plt.colorbar()
plt.show()

# %%
for i in range(5):
    print(np.std(dataset.filtered_images[i]))
# Out:
# 0.4051381778535005
# 2.703197069629624
# 2.9524590966793904
# 2.1881633265077114
# 1.1944997139328368

# %%
len(dataset.patches)
# Out:
# 2375

# %%
k2 = 1.0

for i in range(2375//40):
    k2 = k2 / 1.015
    print(k2)
# Out:
# 0.9852216748768474
# 0.9706617486471404
# 0.9563169937410251
# 0.9421842302867243
# 0.9282603254056397
# 0.9145421925178717
# 0.9010267906580017
# 0.887711123800987
# 0.8745922401980168
# 0.8616672317221842
# 0.8489332332238269
# 0.8363874218953959
# 0.8240270166457103
# 0.8118492774834585
# 0.7998515049098114
# 0.7880310393200113
# 0.7763852604138043
# 0.7649115866145856
# 0.7536074744971287
# 0.7424704182237722
# 0.7314979489889383
# 0.7206876344718605
# 0.7100370782973995
# 0.6995439195048272
# 0.6892058320244604
# 0.67902052416203
# 0.66898573809067
# 0.6590992493504139
# 0.6493588663550877
# 0.6397624299064903
# 0.6303078127157541
# 0.6209929189317774
# 0.6118156836766281
# 0.602774072587811
# 0.5938660813673016
# 0.585089735337243
# 0.5764430890022099
# 0.5679242256179408
# 0.5595312567664441
# 0.5512623219373834
# 0.5431155881156488
# 0.5350892493750234
# 0.5271815264778557
# 0.519390666480646
# 0.5117149423454641
# 0.5041526525571075
# 0.4967021207459188
# 0.4893616953161762
# 0.4821297490799766
# 0.4750046788965287
# 0.4679849053167771
# 0.46106887223327797
# 0.4542550465352493
# 0.44754191776871854
# 0.4409279978016932
# 0.434411820494279
# 0.42799194137367397
# 0.42166693731396454
# 0.4154354062206548
